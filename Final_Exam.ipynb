# %%
########################### Q2 ###############################################################

# %%
# You work in the financial sector and have records of financial transactions from a large number 
#of individuals. You want to figure out which characteristics of the individuals and/or the transactions 
#would be most useful in a predictive model to detect fraud. You don't want to include variables that 
#won't be good at predicting fraud. What type of data science problem is this?

# There is only one correct answer. If you think this fits more than one type of problem, pick the one 
# that fits BEST based on the details given in the question.

# %%
	
# False # Classification

## "Classification is a supervised machine learning method where the model tries to predict the 
## correct label of a given input data"
## Eventually we are supposed to do this, but the problem at hand is getting which variables to use for the model

# %%
# False # Dimensionality Reduction

## Dimensionality reduction mostly takes fractions of variables out, not always whole variable selection
## like in this problem

# %%
# False # Regression

## Same answer as classification, we might use this later, but now we are trying to find out which variable to use.

# %%
# True # Feature Selection

## "Feature Selection is the method of reducing the input variable to your model by using only relevant 
## data and getting rid of noise in data. It is the process of automatically choosing relevant features 
## for your machine learning model based on the type of problem you are trying to solve."
## This above sounds exactly like what we are trying to accomplish

# %%
########################### Q3 ###############################################################

# %%
# We discussed using the GridSearchCV object. Which statement accurately describes why we use it 
# or how it works?

# %%
	
# False # We can use GridSearchCV to optimize only one hyperparameter at a time

## .best_params_ shows the best parameters for the MULTIPLE parameters we optimized for

# %%
# False # We use GridSearchCV to find the optimal train-test split to build our model with

## We do this beforehand, then we perform grid search

# %%
# False # GridSearchCV can only be used with Random Forest Classifiers

## An example from the sklearn page shows grid search being used for svm. Also we wouldn't input RFC like we
## did in HW8 if it only took one classifier.

# %%
# False # The GridSearchCV results always provide exactly one set of results with the highest mean test score

## It provides multiple results, that is why we get the results and get the best rank test score to find
## which parameters are best

# %%
# True # Any parameter that we don't include in our parameter grid will use the default value for all iterations

## This is true for grid search; if you don't specify anything it will just use the default value for 
## that parameter

# %%
########################### Q4 ###############################################################

# %%
# You validate a model using a single test-train split of a data set with a test size of 0.25. 
# The data set contains 1000 observations. The test set for this data would contain 
# 250 #
#  observations. In order to obtain testing sets of the same size with k-fold validation, we would need to use 
# k = 
# 4 #
# . If we do the k-fold validation using our do_Kfold functions, we will generate a total of 
# 8 #
#  scores (total means number of training scores + number of testing scores).

# If the model we are testing is logistic regression, what metric would we use for scoring, i.e. would 
# these scores be accuracy or R2? 
# accuracy #
# (Fill in either accuracy or R2 using those exact terms.)


## 0.25 with 1000 observations translates to 250 for the testing set.
## To have 250 testing, we need k to equal 4 for the 1000 observation set to be split up into testing sets
## with 250 each.
## This means that 4 training scores and 4 testing scores will be produced using our do_Kfold function
## .score() for logistic regression uses accuracy, not R2

# %%
########################### Q5 ###############################################################

# %%
# Both Lasso regression and Random Forest Classifiers can perform feature selection
# True #

# %%
## "Lasso stands for Least Absolute Shrinkage and Selection Operator. It is frequently used in machine 
## learning to handle high dimensional data as it facilitates automatic feature selection"

## "Because RF uses decision trees, it performs “automatic” feature (predictor / variable) selection as 
## part of the model building process."

## They both select features

# %%
########################### Q6 ###############################################################

# %%
# Ensemble models are required to have component models that are all the same type

# False #

# %%
## Ensemble models can have multiple types of component models

# %%
########################### Q7 ###############################################################

# %%
# Feature selection and hyperparameter optimization are the same thing

# False #

# %%
## "Feature Selection is the method of reducing the input variable to your model by using only relevant data and
## getting rid of noise in data. It is the process of automatically choosing relevant features for your machine 
## learning model based on the type of problem you are trying to solve."

## "Hyperparameter optimization finds a tuple of hyperparameters that yields an optimal model which minimizes
## a predefined loss function on given independent data."

## Feature selection chooses which variables to use and which variables not to use, while hyperparameter 
## optimization minimizes the loss function for the variables we specify.

# %%
########################### Q8 ###############################################################

# %% [markdown]
# Consider the Decision Tree shown below. Which statements apply to this tree in terms of how it may have
# been constructed, the underlying data set, and how it is performing classification.  Select ALL that apply,
# there may be more than 1.
#
#
# ![tree_2(1).png](attachment:618cd1b9-7f7e-4ba2-bf73-6f5301dbfb40.png)
#
#
# [You can assume that all less than or equal to amounts send items to the left in the tree]

# %%
# False # There are 4 pure nodes in the tree
## There are no pure nodes as all of the gini values are not 0.
		
# False # The most pure node in the tree is the root
## The gini in the root node (0.75) is actually the highest, so the most IMPURE.
		
# True # More observations have a value for H that is greater than -0.606 as opposed to less than or equal to -0.606
## For the H split, more samples go to the right and are greater that -0.606 (274 samples), than the samples that
## are less than or equal to -0.606 (176).
		
# False # There are 3 classes for the target
## The classes for the target are located where it says value = [___, ___, ___, ___,]. As we can see there are 
## 4 classes for the target
		
# True # The classes in the data set are balanced (nearly exactly the same or exactly the same number of observations)
## The observations are 113, 113, 112, and 112. Yes they are balanced.
		
# True # This tree could have been constructed with the hyperparameter max_depth = 2
## The depth here is 2, so yes.
		
# False # We know for certain that there were only 4 classes in the original data set and 450 total observations
## We could have simply turned a few of the classes into 1 class, meaning that we have no idea of knowing how
## many classes there were in the original data set. We could also have gotten rid of na values.

# %%
########################### Q9 ###############################################################

# %% [markdown]
# Based on this code, which statements apply?
#
#
# ![Screen Shot 2024-04-21 at 9.45.39 AM.png](attachment:5a6a51c5-ccb8-4db2-98b9-a41a59a4f9ab.png)

# %%
# False # There were 8 features in the original data
## There were 6 PCs, so this means there were 6 features in the original data
		
# True # We did not use k-fold cross-validation on this data
## Unless there is no sneaky code before this code listed, from the code given, no, kfold was not run
		
# True # The points are shaded in on the plot according to their predicted class, not their actual class
## This is true, as we use y_pred for the knn.predict(X), which is passed in as the hue.
		
# False # We performed tSNE and then used the tSNE coordinates, as opposed to the original data, for the KNN classification
## Besides the import statement, tSNE is not used anywhere.
		
# True # PCA was used to give us 2 dimensions for plotting the data
## It gave us 6 dimensions, but we took the top 2 for plotting the data.
		
# False # PCA was used to classify each point in the data, that is, to predict a classification for each point
## Knn did this for us, and we shaded the points in accordingly. PCA gave us the dimensions, and Knn gave us
## the predictions
		
# False # Uniform weighting was used for the KNN
## in the knn call it says weights = 'distance'

# %%
########################### Q10 ###############################################################

# %% [markdown]
# You create a histogram to explore values of a variable:
#
#
# ![plot_2.png](attachment:fdd47b16-2956-4607-8c68-251628bcfe43.png)
#
# Based on this histogram, we determine that:

# %%
# True # We expect the median and the mean of this data to be similar to each other (this doesn't mean the same,
# it just means close)
## The mean and median are both in the same general spot.
		
# False # This data is what we call skewed right
## It is roughly bimodal
		
# False # Most of the data has a value less than 2
## There are not many values less than 2
		
# False # The bars will not add up to 1 (100%) since the plot shows counts
## The plot does not show counts

# %%
########################### Q11 ###############################################################

# %%
# The Gini Impurity is a metric that can be used to describe a node in a decision tree. 
# Select the statement below which is accurate with respect to the Gini Impurity.

		
# False # The Gini impurity will always be less in both child nodes than for their parent
## This is just simply not a rule. There is no reason for this to be true. The tree in Q8 also shows that 
## this is untrue.
		
# False # The accuracy of the classifier will be higher when the Gini Impurity is higher
## You want the Gini impurity to be as low as possible.
		
# False # The smallest possible value of the Gini Impurity is -1
## The smallest possible value is 0.0
		
# False # The Gini Impurity increases as the number of features used to split a node increases
## This has no correlation
		
# True # Decision trees are often overfit because by default they seek to make every node as pure as possible
## They get too fit to the specific path of the training data, way more easily than other types of classifiers.
## Also, "In the case of decision tree’s they can learn a training set to a point of high granularity that 
## makes them easily overfit. Allowing a decision tree to split to a granular degree, is the behavior of this 
## model that makes it prone to learning every point extremely well — to the point of perfect classification — 
## ie: overfitting."

# %%
########################### Q12 ###############################################################

# %% [markdown]
# You have a data set with 10 observations in it. The data set has two features, Height and Branches,
# and a target variable, type of Tree, for classification. The data looks like this (this is shown in
# a data frame for reference, it could easily be an array or another format). The data is made up which
# is why you might see some silly patterns in it.
#
#
#
#
#
# ![Screen Shot 2024-04-21 at 10.25.42 AM.png](attachment:003d6e9a-7771-4f88-9567-f87419cd9550.png)
#
# You use the data set to generate this new data set, also with 10 observations:
#
#
#
#
#  ![Screen Shot 2024-04-21 at 10.27.12 AM.png](attachment:abdec600-5fdc-4436-a4a3-71dadfdb730d.png)

# %%
# According to our definitions and examples from class, the process you have performed here is known as:

		
# True # Bootstrapping
## The data is shown, along with another equal length data frame with random samples selected from the
## original data set. This is the definition of bootstrapping. Here is a definition, "In statistics and machine learning, bootstrapping is a resampling technique that involves repeatedly 
## drawing samples from our source data with replacement, often to estimate a population parameter. 
## By “with replacement”, we mean that the same data point may be included in our resampled dataset 
## multiple times."
		
# False # Permutation
## This is combinatorics.
		
# False # Neither of the above
## Bootrsapping is correct

# %%
########################### Q13 ###############################################################

# %% [markdown]
# You have a data set for classification with 8 features and a target with 4 classes.
# You visualize the raw data with PCA:
#
# ![Screen Shot 2024-04-22 at 2.09.08 PM.png](attachment:94e71cb6-4a00-4e44-959c-836a83f1c7d7.png)
#
#
#
# You also look at the components values for the first principal component:
#
#
#
# ![Screen Shot 2024-04-22 at 2.09.17 PM.png](attachment:b2503599-3631-46e6-a3c2-8ffac6dcc8b5.png)

# %%
# Based on this, we can determine (i.e. which of these is true):

# [Remember when it is not specified, we are talking about absolute value.]

		
# True # We expect Var4 and Var6 to be most highly associated with the target, i.e. we would select these as 
# important features
## Var4 and Var6 both have the lowest and the highest componets respectively, but they also both have the two
## highest magnitudes. This means that they are most highly associated with the target.
		
# False # Observations with larger positive values of Var1 and Var6 will tend to be on the right hand side of 
# the PCA scatterplot
## 
		
# This data will work well with any classifier since we see clearly separated groups (groups with space 
# between them) related to the target values
##
		
# False # Var2 makes the smallest contribution to PC1
## Var2 has a moderate contribution to PC1

# %%
############ INVESTIGATE THESE ANSWER CHOICES FURTHER #############################

# %%
########################### Q14 ###############################################################

# %%
# Suppose you have a very small data set that you will be using for regression- it's not great 
# in practice, but it makes things easier since this is an exam :)

# You decide to use a single test-train split, and divide the data into testing and training. 
# The data shown below is only the features - it does not include the target.

# %% [markdown]
# ![Screen Shot 2022-11-25 at 4.53.23 PM.png](attachment:c6082dd8-2c09-4731-b4f8-aaa8aaf16357.png)

# %% [markdown]
# ![Screen Shot 2022-11-25 at 4.56.49 PM.png](attachment:cdc8fe52-51d4-4bf5-873b-1509eb6691b6.png)

# %%
import pandas as pd
 
data1 = {'VarA': [8, 7, 6, 5, 6, 9, 6, 9, 6], 'VarB': [732, 612, 860, 899, 741, 720, 806, 941, 515]} 

Xtrain = pd.DataFrame(data1)
 
print(Xtrain)

data2 = {'VarA': [5, 6, 9], 'VarB': [639, 855, 765]} 

Xtest = pd.DataFrame(data2)
 
print(Xtest)
# Out:
#    VarA  VarB
# 0     8   732
# 1     7   612
# 2     6   860
# 3     5   899
# 4     6   741
# 5     9   720
# 6     6   806
# 7     9   941
# 8     6   515
#    VarA  VarB
# 0     5   639
# 1     6   855
# 2     9   765

# %%
# You re-scale this data using standard scaling, using the scaling procedures in the same way 
# we have in class. 

from sklearn.preprocessing import StandardScaler as SS
ss = SS()
Xtrain_s = ss.fit_transform(Xtrain)
Xtest_s = ss.transform(Xtest)

print(f"Xtrain Scaled: \n {Xtrain_s} \n \n Xtest Scaled: \n {Xtest_s}")
# Out:
# Xtrain Scaled:
#  [[ 0.81110711 -0.20562739]
#  [ 0.08111071 -1.13872646]
#  [-0.64888568  0.78967829]
#  [-1.37888208  1.09293549]
#  [-0.64888568 -0.13564496]
#  [ 1.5411035  -0.2989373 ]
#  [-0.64888568  0.36978371]
#  [ 1.5411035   1.41952016]
#  [-0.64888568 -1.89298154]]
#
#  Xtest Scaled:
#  [[-1.37888208 -0.92877917]
#  [-0.64888568  0.75079916]
#  [ 1.5411035   0.05097486]]

# %%
### By hand just to check
import numpy as np

# print(np.std(Xtrain))
# print(np.mean(Xtrain))

### For the first value to check
print(Xtrain_s[0][0])
print((Xtrain['VarA'][0] - np.mean(Xtrain['VarA'])) / (np.std(Xtrain)[0]))

### It matches up to the accuracy of 0.0000000000000001
# Out:
# 0.8111071056538124
# 0.8111071056538125
# /tmp/ipykernel_121/3434146453.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print((Xtrain['VarA'][0] - np.mean(Xtrain['VarA'])) / (np.std(Xtrain)[0]))

# %%
# Based on this, what is the re-scaled value for Var_B in the first observation in 
# the testing data? Give your answer to 3 decimal places.

print(Xtest_s[0][1])
print((Xtest['VarB'][0] - np.mean(Xtrain['VarB'])) / (np.std(Xtrain)[1]))
print(-0.929)
# Out:
# -0.9287791679992358
# -0.9287791679992358
# -0.929
# /tmp/ipykernel_121/4110880464.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print((Xtest['VarB'][0] - np.mean(Xtrain['VarB'])) / (np.std(Xtrain)[1]))

# %%
########################### Q15 ###############################################################

# %%
# We constructed linear regression models both with and without regularization. 
# Which statement applies when we consider regularization with linear models?

		
# False # Regularization constrains the values of the target predictions
## It constrains the values of the features from making the model overfit
		
# False # Regularization prevents the model from overfitting the test data
## Regularization HELPS prevent the model from overfitting to the TRAINING data, instead.
		
# True # Lasso and Ridge regression use different cost functions
## They use different cost functions: Lasso using absolute value, and Ridge using the square of itself.
		
# False # The purpose of regularization is to remove observations that are not useful for building the model
## That is cleaning the data. Regularization is used for further limiting and sometimes removing variables by 
## assigning a weight to the regression.

# %%
########################### Q16 ###############################################################

# %%
# You conduct a GridSearch with cross-validation as part of your model development process. Assume that all 
# proper import lines are included and that you have already created your model (i.e. some kind of classifier 
# or regressor of interest) and assigned it the name my_model. The code you run is:

# param_grid = dict(C=np.linspace(0.01,10,100)) 
# cv = KFold(n_splits=10, random_state = 201, shuffle = True)
# grid = GridSearchCV(my_model, param_grid=param_grid, cv=cv,scoring='accuracy')

# You obtain the following output after fitting the grid to your data:

# The best parameters are {'C': 0.1109090909090909} with a score of 0.82

# Based on this, which of the following statements apply? Keep in mind that some answers reflect the standard 
# procedures we have used in class all semester,
# so select your answers based on how we have done things in class.



# False # If the original data had 4000 data points, each training set would have 400 observations in it
## Each training set would have 3600 observations in it. Each testing set would have 400 observations in it.


# True # For this particular hyperparameter, the optimal value indicated in the output constrains the model more 
# than the default value, which is 1.
## A good explanation of C is, "A high value of C tells the model to give high weight to the training data, and a lower weight to the 
## complexity penalty. A low value tells the model to give more weight to this complexity penalty at the 
## expense of fitting to the training data. Basically, a high C means "Trust this training data a lot", 
## while a low value says "This data may not be fully representative of the real world data, so if it's 
## telling you to make a parameter really large, don't listen to it"."
## In other words, the low optimal value for C here gives more weight to the complexity penalty and constrains
## the model more. 


# True # A total of 1000 models were fit
## Here we have 10 splits so for every iteration we fit 10 models. Then we have 100 iterations so we have 1000
## models total.

		
# True # We are choosing the best value of the hyperparameter based on the highest average training score
## This is whole point of using training and testing data. You use this grid search and find optimal 
## hyperparameters on the training data, and then use it to test on the testing data.

		
# False # The score printed out tells us that 82% of the variation in the value of the target was explained 
# by the model
## This explanation is for R2, not accuracy. We are using accuracy here.


# False # my_model could be a Ridge or Lasso regressor
## We get a C value (not a parameter for Ridge or Lasso, with scoring based on accuracy (R2 is used for Ridge and
## Lasso.

		
# False # We would expect that the input data for the GridSearch is already all on the same scale and/or has been 
# re-scaled already
## We cannot assume anything like this based on the code above.

# %%
########################### Q17 ###############################################################

# %% [markdown]
# You conduct a Grid Search to find optimal hyperparameters for a Random Forest Classifier. Based on the results
# shown below, what can you conclude? ALL results are shown (nothing has been omitted from the rows or columns)
# so your answers should be entirely based on the results shown below (do not overthink about things that might
# be left out and tricks, there are none).
#
#
#
#
# ![rfc_grid_3.png](attachment:ea97c6dc-6b5a-4fc3-81be-2d08746c5f6f.png)

# %%
# True # In the optimal results, the value of min_samples leaf is not the one that would constrain the 
# tree the most
## min_samples leaf = 9, instead of 8, would constrain the tree the most because it is a floor for the values.


# False # The classifier performed better in all cases with more trees in the random forest (holding the other 
# hyperparameters constant)
## The scores do not have that trend

		
# False # Only one optimal combination of hyperparameters was identified in the GridSearch
## There are more than 1

		
# False # Based on these results, there were 8 combinations of hyperparameters tested
## There are much more than 8.

# %%
########################### Q18 ###############################################################

# %% [markdown]
# You create a k-nearest neighbors classifier using n_neighbors = 8 and uniform (NOT distance) weighting.
# You run this classifier on a single test-train split of a data set.
#
# The confusion matrix for the test data is:
#
# ![Screen Shot 2024-04-22 at 9.18.44 AM.png](attachment:7219f655-77f2-49a6-ad77-fc7fe58c00af.png)

# %% [markdown]
# You create a k-nearest neighbors classifier using n_neighbors = 8 WITH distance weighting.
# You run this classifier on THE SAME single test-train split as used above.
#
# The confusion matrix for the test data  is:
#
#
#
# ![Screen Shot 2024-04-22 at 9.18.56 AM.png](attachment:c3fe8c0b-44a5-477c-b5a2-334aff58314f.png)

# %%
# Based on this we can conclude:



# [The word rare is not a trick. Rare means something that does not occur often. Rarest means the thing 
# that occurs least often.]

		
# False # There were 35 observations that truly belonged to the COPD class in the data set when we used distance 
# weighting, but there were only 33 that truly belonged to the COPD class in the data set when we used uniform 
# weighting
## This would be true if we were looking at the predicted, but the actual shows different numbers.

		
# False # When we used distance weighting, the overall accuracy (i.e. total, across all classes) improved
print("The total accuracy for uniform weighting is", (49 + 25 + 0) / (49 + 7 + 0 + 19 + 25 + 0 + 10 + 1 + 0))
## The total accuracy for uniform weighting is 0.66.
print("The total accuracy for distance weighting is", (48 + 26 + 0) / (48 + 8 + 0 + 17 + 26 + 1 + 10 + 1 + 0))
## The total accuracy for distance weighting is 0.66.
## No improvement
		
# True # Using distance weighting improved recall for COPD, but not for CF
print("The recall for COPD with uniform weighting is", (25) / (25 + 19))
print("The recall for COPD with distance weighting is", (26) / (26 + 17 + 1))
print("The recall for CF with uniform weighting is", (49) / (49 + 7))
print("The recall for CF with distance weighting is", (48) / (48 + 8))
		
# True # The recall for the rarest class in the test data shown is 0 regardless of whether we used distance 
# weighting or not
print("The recall for IPF with uniform weighting is", (0) / (0 + 1 + 10))
print("The recall for IPF with distance weighting is", (0) / (0 + 1 + 10))

		
# False # One of the classes was not observed in the test data at all
## IPF DOES have some observations. It has 11, they were just all mistakenly classified as other classes.

		
# False # There were 3 classes in the original data
## We know nothing about the original data

		
# True # The classifier cannot predict one of the classes because the training data did not create an equation 
# that works well for this class
## This seems to be a good explanation

##################### LOOK OVER THIS ONE, REALLY MOSTLY THE LAST ANSWER!!!!!!!!##########################
# Out:
# The total accuracy for uniform weighting is 0.6666666666666666
# The total accuracy for distance weighting is 0.6666666666666666
# The recall for COPD with uniform weighting is 0.5681818181818182
# The recall for COPD with distance weighting is 0.5909090909090909
# The recall for CF with uniform weighting is 0.875
# The recall for CF with distance weighting is 0.8571428571428571
# The recall for IPF with uniform weighting is 0.0
# The recall for IPF with distance weighting is 0.0

# %%
########################### Q19 ###############################################################

# %% [markdown]
# Consider the following screenshot which shows a few rows of data from a data frame and code that uses this data frame:
#
#
#
# ![Screen Shot 2021-11-30 at 4.30.38 PM.png](attachment:d819e6be-3242-4754-99c3-004d32972a3e.png)

# %%
# Based on the data and the code, and the way we have used this code in our class, what type of
# analysis will be carried out on this data?

		
# True # Regression
## We disclude the catagorical variables and assemble the numeric. This makes it look like we will use
## a regression of some type

		
# False # Classification
## We filter out the catagorical variables

		
# False # Dimensionality reduction
## We have a very small amount of dimensions. There is no need for dimensionality reduction.

# %%
########################### Q20 ###############################################################

# %%
# You have a data set that describes liver disease. There is a variable called stage that describes 
# the advancement of the disease. Stage is determined by a doctor when they look at a microscope slide
# showing liver cells, and is up to their opinion. Stage is encoded in the data as 1,2,3, or 4 - with 
# one being least severe and 4 being most severe.

# Using this information, which of the following statistics (or sets thereof) and/or plots would be 
# appropriate to use to report on the values of stage? Select ALL that would be valid.

# %% [markdown]
# mean       3.039855
# stdev        0.853999
#
# \# False #
#
# \## The mean and sd are useless because this is nominal data.

# %% [markdown]
# ![box.png](attachment:58ba3fec-13c1-436c-8839-1390687753c2.png)
#
# \# False #
#
# \## Percentiles and medians are useless because this is nominal data.

# %% [markdown]
# ![bar.png](attachment:40c6a1fa-542d-401d-aaf6-ccb3d76bc0ed.png)
#
# \# True #
#
# \## Frequency distributions are useful for nominal data.

# %% [markdown]
# ![Screen Shot 2023-11-25 at 3.52.14 PM.png](attachment:ea2bcc3b-352d-4e52-b9da-5b5405aa86a0.png)
#
# [unique = # unique values; top = mode; freq = freq of mode]
#
# \# True #
#
# \## The total count, unique values, the mode, and the frequency of the mode are all very useful when looking
# at nominal data.

# %% [markdown]
#
# 3.0 &nbsp;  111
#
# 4.0   &nbsp;  94
#
# 2.0  &nbsp;   59
#
# 1.0  &nbsp;   12
#
# Name: Stage, dtype: int64
#
# (value_counts)
#
# \# True #
#
# \## The counts of each variable are useful for nominal data.

# %%
########################### Q21 ###############################################################

# %% [markdown]
# You run the following code to perform logistic regression. You can assume there are no issues with X and y themselves (i.e. NO TRICKS, there are NO TRICKS anywhere). However, there is a problem with your code. What is it?
#
#
# ![Screen Shot 2024-04-21 at 10.08.17 AM.png](attachment:3907669d-bed8-4a7c-9fde-97b7a810b364.png)

# %%
# False # The value of the hyperparameter is invalid
## C = 0.8 is completely valid.
		
# False # The training and testing sets of data are incorrectly assigned
## They are assigned properly.
		
# False # The data is not scaled properly
## It is scaled just fine.
		
# True # The logistic regression is not fit properly
## Our error is where you fit the model twice. This results in the log_reg model being fit to the testing data.

# False # None of these
## The answer above is true

# %% [markdown]
# Sources
#
# https://www.simplilearn.com/tutorials/machine-learning-tutorial/feature-selection-in-machine-learning#:~:text=ProgramExplore%20Program-,What%20is%20Feature%20Selection%3F,you%20are%20trying%20to%20solve.
#
# https://www.geeksforgeeks.org/dimensionality-reduction/
#
# https://www.analyticsvidhya.com/blog/2020/10/feature-selection-techniques-in-machine-learning/
#
# https://www.datacamp.com/blog/classification-machine-learning
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
#
# https://scikit-learn.org/stable/modules/grid_search.html
#
# https://stackoverflow.com/questions/73204541/sklearn-girdsearchcv-uses-default-parameters-instead-of-param-grid
#
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html
#
# https://scikit-learn.org/stable/modules/cross_validation.html
#
# https://www.quora.com/Can-we-use-Random-Forest-or-LASSO-to-do-feature-selection-if-many-features-contain-mass-zeros
#
# https://gsverhoeven.github.io/post/random-forest-rfe_vs_tuning/#:~:text=Because%20RF%20uses%20decision%20trees,used%20to%20explain%20this%20result.
#
# https://stackoverflow.com/questions/30919454/sklearn-how-to-make-an-ensemble-for-two-binary-classifiers
#
# https://stackoverflow.com/questions/21498875/when-using-multiple-classifiers-how-to-measure-the-ensembles-performance-sc
#
# https://stackoverflow.com/questions/21498875/when-using-multiple-classifiers-how-to-measure-the-ensembles-performance-sc
#
# https://en.wikipedia.org/wiki/Hyperparameter_optimization#:~:text=Hyperparameter%20optimization%20finds%20a%20tuple,and%20returns%20the%20associated%20loss.
#
# https://www.geeksforgeeks.org/gini-impurity-and-entropy-in-decision-tree-ml/
#
# https://statusneo.com/roots-of-choice-understanding-decision-trees/
#
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
#
# https://study.com/academy/lesson/frequency-histogram-definition-examples.html#:~:text=Frequency%20is%20a%20count%20of,points%20within%20that%20bar's%20range.
#
# https://www.quora.com/Why-do-decision-trees-have-a-tendency-to-overfit-to-the-training-set
#
# https://carpentries-incubator.github.io/machine-learning-novice-python/07-bootstrapping/index.html#:~:text=In%20statistics%20and%20machine%20learning,our%20resampled%20dataset%20multiple%20times.
#
# https://saturncloud.io/blog/what-is-sklearn-pca-explained-variance-and-explained-variance-ratio-difference/#:~:text=and%20so%20on.-,Explained%20Variance%20in%20Sklearn%20PCA,eigenvalue%20associated%20with%20that%20component.
#
# https://stackoverflow.com/questions/50796024/feature-variable-importance-after-a-pca-analysis
#
# https://stackoverflow.com/questions/40758562/can-anyone-explain-me-standardscaler
#
# https://medium.com/@gowthamsr37/which-feature-scaling-technique-to-use-standardization-vs-normalization-9dcf8eafdf8c
#
# https://www.geeksforgeeks.org/different-ways-to-create-pandas-dataframe/
#
# https://flexiple.com/python/python-new-line#:~:text=The%20New%20Line%20Character,-The%20new%20line&text=When%20%5Cn%20is%20included%20in,%22%20and%20%22Python!%22.
#
# https://www.geeksforgeeks.org/formatted-string-literals-f-strings-python/
#
# https://numpy.org/doc/stable/reference/generated/numpy.std.html
#
# https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html
#
# https://medium.com/@sahin.samia/mregularization-in-regression-tackling-overfitting-for-enhanced-model-performance-553f2cef02df
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html#sklearn.model_selection.GridSearchCV.score
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.KFold.html
#
# https://stackoverflow.com/questions/67513075/what-is-c-parameter-in-sklearn-logistic-regression#:~:text=C%3A%20float%2C%20default%3D1.0,smaller%20values%20specify%20stronger%20regularization.
#
# https://stackoverflow.com/questions/67513075/what-is-c-parameter-in-sklearn-logistic-regression
#
# https://stackoverflow.com/questions/44459845/gridsearchcv-best-score-meaning-when-scoring-set-to-accuracy-and-cv
#
# https://stats.stackexchange.com/questions/453221/should-i-use-gridsearchcv-on-all-of-my-data-or-just-the-training-set
#
# https://www.youtube.com/watch?v=TCpN2eKGrIY
#
# https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html
#
# https://bobbyhadz.com/blog/jupyter-notebook-add-newline-in-markdown
#
# https://www.dotcms.com/docs/latest/markdown-syntax
#
# https://stackoverflow.com/questions/21532667/numpy-histogram-cumulative-density-does-not-sum-to-1
#
# https://github.com/matplotlib/matplotlib/issues/10398/
#
# https://matplotlib.org/devdocs/gallery/statistics/hist.html#sphx-glr-gallery-statistics-hist-py
#
# https://stackoverflow.com/questions/9767241/setting-a-relative-frequency-in-a-matplotlib-histogram
#
# https://stackoverflow.com/questions/68359759/density-distribution-and-bar-plot-from-x-and-y-data
#
# https://www.medcalc.org/manual/frequencies-bar-charts.php
#
# https://www.quora.com/Can-a-bimodal-distribution-have-two-modes-and-two-medians
#
# https://www.graphpad.com/guides/prism/latest/statistics/the_different_kinds_of_variabl.htm
#
# https://www.graphpad.com/support/faq/what-is-the-difference-between-ordinal-interval-and-ratio-variables-why-should-i-care/#:~:text=Examples%20of%20ordinal%20variables%20include,%2C%20%E2%80%9Cextremely%20like%E2%80%9D).
#
# https://www.graphpad.com/support/faq/what-is-the-difference-between-ordinal-interval-and-ratio-variables-why-should-i-care/#:~:text=You%20can%20code%20nominal%20variables,race%2C%20eye%20color%2C%20political%20party
